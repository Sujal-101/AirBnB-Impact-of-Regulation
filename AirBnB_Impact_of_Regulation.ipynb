# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 40px; font-weight: bold;">
#     <strong> AirBnB Listings and Reviews </strong>
#   </h1>
# </div>

# %% [markdown]
# <img src="https://www.smarthouse.com.au/wp-content/uploads/2024/03/image-airbnb-scaled-1.jpg" width=1200>

# %% [markdown]
# <div style="background-color: #0000; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong>Exploratory Data Analysis</strong>
#   </h1>
# </div>

# %%
reviews_dict = pd.read_csv(r"C:\Users\sujal patil\OneDrive\Desktop\Python Project Dataset\Airbnb Data\Reviews_data_dictionary.csv")

# %%
reviews_dict
# Out:
#          Field  Description
# 0   listing_id   Listing ID
# 1    review_id    Review ID
# 2         date  Review date
# 3  reviewer_id  Reviewer ID

# %%
reviews = pd.read_csv(r"C:\Users\sujal patil\OneDrive\Desktop\Python Project Dataset\Airbnb Data\Reviews.csv")

# %%
reviews.head()
# Out:
#    listing_id  review_id        date  reviewer_id
# 0       11798  330265172  2018-09-30     11863072
# 1       15383  330103585  2018-09-30     39147453
# 2       16455  329985788  2018-09-30      1125378
# 3       17919  330016899  2018-09-30    172717984
# 4       26827  329995638  2018-09-30     17542859

# %%
reviews.shape
# Out:
# (5373143, 4)

# %%
listings_dict = pd.read_csv(r"C:\Users\sujal patil\OneDrive\Desktop\Python Project Dataset\Airbnb Data\Listings_data_dictionary.csv")

# %%
listings_dict
# Out:
#                           Field  \
# 0                    listing_id
# 1                          name
# 2                       host_id
# 3                    host_since
# 4                 host_location
# 5            host_response_time
# 6            host_response_rate
# 7          host_acceptance_rate
# 8             host_is_superhost
# 9     host_total_listings_count
# 10         host_has_profile_pic
# 11       host_identity_verified
# 12                neighbourhood
# 13                     district
# 14                         city
# 15                     latitude
# 16                    longitude
# 17                property_type
# 18                    room_type
# 19                 accommodates
# 20                     bedrooms
# 21                    amenities
# 22                        price
# 23               minimum_nights
# 24               maximum_nights
# 25         review_scores_rating
# 26       review_scores_accuracy
# 27    review_scores_cleanliness
# ...

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Loading and Checking the dataset </strong>
#   </h1>
# </div>

# %%
listings = pd.read_csv(r"C:\Users\sujal patil\OneDrive\Desktop\Python Project Dataset\Airbnb Data\Listings.csv",
                       encoding = "ISO-8859-1",low_memory=False)

# %%
import warnings
warnings.filterwarnings('ignore')

#Prevents warnings from showing up in the output.
#Keeps the output clean, especially in data analysis code where some libraries throw non-critical warnings.

# %%
listings.head()
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_response_time  \
# 0  2011-12-03  Paris, Ile-de-France, France                NaN
# 1  2013-11-29  Paris, Ile-de-France, France                NaN
# 2  2014-07-31  Paris, Ile-de-France, France                NaN
# 3  2013-12-17  Paris, Ile-de-France, France                NaN
# 4  2014-12-14  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279712 entries, 0 to 279711
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   279712 non-null  int64
#  1   name                         279537 non-null  object
#  2   host_id                      279712 non-null  int64
#  3   host_since                   279547 non-null  object
#  4   host_location                278872 non-null  object
#  5   host_response_time           150930 non-null  object
#  6   host_response_rate           150930 non-null  float64
#  7   host_acceptance_rate         166625 non-null  float64
#  8   host_is_superhost            279547 non-null  object
#  9   host_total_listings_count    279547 non-null  float64
#  10  host_has_profile_pic         279547 non-null  object
#  11  host_identity_verified       279547 non-null  object
# ...

# %%
listings["host_since"] = pd.to_datetime(listings["host_since"])

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Information About the Dataset </strong>
#   </h1>
# </div>

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279712 entries, 0 to 279711
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   279712 non-null  int64
#  1   name                         279537 non-null  object
#  2   host_id                      279712 non-null  int64
#  3   host_since                   279547 non-null  datetime64[ns]
#  4   host_location                278872 non-null  object
#  5   host_response_time           150930 non-null  object
#  6   host_response_rate           150930 non-null  float64
#  7   host_acceptance_rate         166625 non-null  float64
#  8   host_is_superhost            279547 non-null  object
#  9   host_total_listings_count    279547 non-null  float64
#  10  host_has_profile_pic         279547 non-null  object
#  11  host_identity_verified       279547 non-null  object
# ...

# %%
listings["city"].value_counts()
# Out:
# city
# Paris             64690
# New York          37012
# Sydney            33630
# Rome              27647
# Rio de Janeiro    26615
# Istanbul          24519
# Mexico City       20065
# Bangkok           19361
# Cape Town         19086
# Hong Kong          7087
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Columns and Rows Filtering </strong>
#   </h1>
# </div>

# %%
#filtering the rows and columns using query function
paris_listings = listings.query("city == 'Paris'").loc[:,["host_since","neighbourhood","city","accommodates","price"]]

# %%
paris_listings
# Out:
#        host_since      neighbourhood   city  accommodates  price
# 0      2011-12-03  Buttes-Montmartre  Paris             2     53
# 1      2013-11-29  Buttes-Montmartre  Paris             2    120
# 2      2014-07-31             Elysee  Paris             2     89
# 3      2013-12-17          Vaugirard  Paris             2     58
# 4      2014-12-14              Passy  Paris             2     60
# ...           ...                ...    ...           ...    ...
# 279707 2015-04-13       Observatoire  Paris             2    120
# 279708 2013-11-27  Buttes-Montmartre  Paris             2     60
# 279709 2012-04-27  Buttes-Montmartre  Paris             2     50
# 279710 2015-07-16         Popincourt  Paris             2    105
# 279711 2013-06-17  Enclos-St-Laurent  Paris             2     70
#
# [64690 rows x 5 columns]

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Paris City Data Analysis </strong>
#   </h1>
# </div>

# %%
paris_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64690 entries, 0 to 279711
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_since     64657 non-null  datetime64[ns]
#  1   neighbourhood  64690 non-null  object
#  2   city           64690 non-null  object
#  3   accommodates   64690 non-null  int64
#  4   price          64690 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 3.0+ MB

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Checking if there are missing values in the dataset </strong>
#   </h1>
# </div>

# %%
paris_listings.isna().sum()
# Out:
# host_since       33
# neighbourhood     0
# city              0
# accommodates      0
# price             0
# dtype: int64

# %%
paris_listings.dropna(how = "any",inplace = True)

# %%
paris_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64657 entries, 0 to 279711
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_since     64657 non-null  datetime64[ns]
#  1   neighbourhood  64657 non-null  object
#  2   city           64657 non-null  object
#  3   accommodates   64657 non-null  int64
#  4   price          64657 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 3.0+ MB

# %%
paris_listings.describe(include = "object")
# Out:
#             neighbourhood   city
# count               64657  64657
# unique                 20      1
# top     Buttes-Montmartre  Paris
# freq                 7232  64657

# %%
paris_listings[paris_listings["accommodates"] == 0].count()
# Out:
# host_since       54
# neighbourhood    54
# city             54
# accommodates     54
# price            54
# dtype: int64

# %%
paris_listings[paris_listings["price"] == 0].count()
# Out:
# host_since       62
# neighbourhood    62
# city             62
# accommodates     62
# price            62
# dtype: int64

# %%
paris_listings[(paris_listings["accommodates"] != 0) & (paris_listings["price"] == 0)]
# Out:
#        host_since      neighbourhood   city  accommodates  price
# 207075 2019-07-22          Vaugirard  Paris             2      0
# 207076 2019-10-31  Enclos-St-Laurent  Paris             2      0
# 208301 2019-05-27     Palais-Bourbon  Paris             2      0
# 208302 2019-07-19           Pantheon  Paris             3      0
# 208854 2016-09-16             Louvre  Paris             3      0
# 208855 2019-11-06         Luxembourg  Paris             3      0
# 208856 2019-12-02             Elysee  Paris             3      0
# 208857 2019-12-17              Opera  Paris             2      0

# %%
paris_listings = paris_listings[paris_listings["price"] != 0]

# %%
paris_listings.head()
# Out:
#   host_since      neighbourhood   city  accommodates  price
# 0 2011-12-03  Buttes-Montmartre  Paris             2     53
# 1 2013-11-29  Buttes-Montmartre  Paris             2    120
# 2 2014-07-31             Elysee  Paris             2     89
# 3 2013-12-17          Vaugirard  Paris             2     58
# 4 2014-12-14              Passy  Paris             2     60

# %%
paris_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64595 entries, 0 to 279711
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_since     64595 non-null  datetime64[ns]
#  1   neighbourhood  64595 non-null  object
#  2   city           64595 non-null  object
#  3   accommodates   64595 non-null  int64
#  4   price          64595 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 3.0+ MB

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Finding average Price of AirBnB in Paris as per Localities </strong>
#   </h1>
# </div>

# %%
paris_listings_neighbourhood = paris_listings.groupby("neighbourhood"
                                                     ).agg(avg_price = ("price","mean")).sort_values("avg_price",ascending = False).round(2)

# %%
paris_listings_neighbourhood
# Out:
#                      avg_price
# neighbourhood
# Elysee                  211.37
# Louvre                  175.75
# Passy                   161.29
# Palais-Bourbon          157.51
# Luxembourg              155.79
# Bourse                  149.63
# Hotel-de-Ville          144.52
# Temple                  138.43
# Pantheon                122.98
# Opera                   119.20
# Vaugirard               107.09
# Enclos-St-Laurent       103.12
# Batignolles-Monceau     102.69
# Observatoire            102.00
# Gobelins                 98.11
# Popincourt               90.55
# Reuilly                  89.13
# Buttes-Montmartre        87.25
# Buttes-Chaumont          82.69
# Menilmontant             74.93

# %%
paris_listings_accommodates = paris_listings.groupby("accommodates")["price"].mean().sort_values(
    ascending = False).round(2)

# %%
paris_listings_accommodates
# Out:
# accommodates
# 15    928.42
# 12    821.43
# 13    704.58
# 14    699.23
# 11    680.91
# 16    677.06
# 10    585.76
# 9     381.90
# 8     325.02
# 7     261.07
# 6     217.19
# 5     165.19
# 4     126.00
# 3      98.30
# 2      84.09
# 1      64.85
# Name: price, dtype: float64

# %%
paris_listings_accommodates_Elysee = paris_listings.query("neighbourhood == 'Elysee'"
                                                         ).groupby("accommodates").agg(avg_price = ("price","mean"))

# %%
# Inside of Paris,the price of AirBnB is directly impacted by the popularity of the tourist place or
# the view of Eiffel tower. We need to further see if the prices are increasing when the regulations are imposed

# %%
paris_listings_accommodates_Elysee
# Out:
#                avg_price
# accommodates
# 1              79.522222
# 2             155.103352
# 3             153.882759
# 4             212.096070
# 5             328.817073
# 6             355.508571
# 7             411.538462
# 8             405.518519
# 9             440.272727
# 10            500.857143
# 11            805.000000
# 12            529.625000
# 13            842.500000
# 14            971.000000
# 16            800.000000

# %%
# The AirBnB with 14 people accommodates is the expensive, even more expensive the 16 accommodates
# the same trend is spotted for 11 and 12 accommodates. Every other accommodation looks reasonable.

# %% [markdown]
# ### Possible reasons for this trend
# 1. Owners of properties with 16 people might face occupancy issues due to less number of large groups.
# 2. The ones with 14 people might be a sweet spot for a group having two families travelling.
# 3. There is possibility that more than 16 and 12 occupancy properties are away from hotspots in Elysee.
# 4. There might be potential outliers in 11 and 14 occupancy properties which are skewing the trend.

# %%
paris_listings["year"] = paris_listings["host_since"].dt.year

# %%
paris_listings.head()
# Out:
#   host_since      neighbourhood   city  accommodates  price  year
# 0 2011-12-03  Buttes-Montmartre  Paris             2     53  2011
# 1 2013-11-29  Buttes-Montmartre  Paris             2    120  2013
# 2 2014-07-31             Elysee  Paris             2     89  2014
# 3 2013-12-17          Vaugirard  Paris             2     58  2013
# 4 2014-12-14              Passy  Paris             2     60  2014

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Finding popularity of AirBnB over time </strong>
#   </h1>
# </div>

# %%
paris_listings_over_time = paris_listings.groupby("year").agg(total_new_hosts = ("year", "count"),
                                                             average_price = ("price", "mean"))

# %%
paris_listings_over_time
# Out:
#       total_new_hosts  average_price
# year
# 2008                4      77.750000
# 2009              106     159.641509
# 2010              416     125.031250
# 2011             1339     124.828230
# 2012             4592     111.578615
# 2013             8142     107.096414
# 2014            10922     100.253800
# 2015            12147     103.646250
# 2016             8867     114.211345
# 2017             4585     108.658888
# 2018             4294     138.209362
# 2019             5685     129.962533
# 2020             3363     143.517098
# 2021              133      93.488722

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
paris_listings_neighbourhood
# Out:
#                      avg_price
# neighbourhood
# Elysee                  211.37
# Louvre                  175.75
# Passy                   161.29
# Palais-Bourbon          157.51
# Luxembourg              155.79
# Bourse                  149.63
# Hotel-de-Ville          144.52
# Temple                  138.43
# Pantheon                122.98
# Opera                   119.20
# Vaugirard               107.09
# Enclos-St-Laurent       103.12
# Batignolles-Monceau     102.69
# Observatoire            102.00
# Gobelins                 98.11
# Popincourt               90.55
# Reuilly                  89.13
# Buttes-Montmartre        87.25
# Buttes-Chaumont          82.69
# Menilmontant             74.93

# %%
plt.figure(figsize = (12,8))
sns.barplot(data = paris_listings_neighbourhood,
           y = paris_listings_neighbourhood.index,
           x = paris_listings_neighbourhood.avg_price, color = "#FF5A5F")
plt.title("Neighbourhood in Paris (Premium Localities at the Top!)")
plt.xlabel("How expensive? (Euros)")
plt.ylabel("Prominent Places with AirBnBs")
plt.show()

# %%
# Inside of Paris, the price of AirBnBs is directly impacted by the popularity of the tourist place or 
# the view of Eiffel tower. We need to further see if the prices are increasing when the regulations are imposed.

# %%
paris_listings_accommodates_Elysee.avg_price.sort_values(ascending = False)
# Out:
# accommodates
# 14    971.000000
# 13    842.500000
# 11    805.000000
# 16    800.000000
# 12    529.625000
# 10    500.857143
# 9     440.272727
# 7     411.538462
# 8     405.518519
# 6     355.508571
# 5     328.817073
# 4     212.096070
# 2     155.103352
# 3     153.882759
# 1      79.522222
# Name: avg_price, dtype: float64

# %%
# step 1: sort the data by avg_price
df_sorted = paris_listings_accommodates_Elysee.sort_values("avg_price", ascending = True)

# step 2: prepare values for barh()
x = df_sorted["avg_price"].values
y = df_sorted.index.astype(str)  #convert index to string for y axis

# step 3: plot using matplotlib
plt.figure(figsize=(12,8))
plt.barh(y=y, width = x, color = "#00a699")

plt.title("Average Price of AirBnB in Elysee --vs-- Number of People that can stay")
plt.xlabel("Average Price (Euros)")
plt.ylabel("Number of People that can staay")
plt.tight_layout()
plt.show()

# %%
# The AirBnBs with 14 people accomodation is the costliest, even costlier than 16 accomodates. 
# the same trend is spotted for 11 and 12 accomodates. Every other accomodation looks reasonable.

# %%
plt.figure(figsize = (12,8))
sns.lineplot(data = paris_listings_over_time["total_new_hosts"],color = "#FC642D", marker = "o")
plt.xlabel("Years")
plt.ylabel("Number of AirBnBs and Localities")
plt.title("Popularity of AirBnBs over time")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.lineplot(data = paris_listings_over_time["average_price"],color = "#484848", marker = "o")
plt.xlabel("Years")
plt.ylabel("Average Price")
plt.title("Average Price of AirBnBs over time")
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Finding effects of Regulations on AirBnB Business </strong>
#   </h1>
# </div>

# %%
fig, ax = plt.subplots()
ax.plot(paris_listings_over_time.index,paris_listings_over_time["total_new_hosts"],
       label = "New Hosts", c = "green")

ax.set_ylabel("New Hosts")

ax2 = ax.twinx()

ax2.plot(paris_listings_over_time.index,paris_listings_over_time["average_price"],
       label = "Average Price", c = "red")

ax2.set_ylabel("Average Price")

ax2.set_ylim(0)

ax.set_title("Regulations Lead to Fewer New Hosts and Higher Prices")

plt.show()

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Final Insights </strong>
#   </h1>
# </div>

# %% [markdown]
# 1. Initially, both the number of AirBnBs and their prices increased due to early traction and interest from early adopters.
# 2. As AirBnB became widely known and commonly used, the number of listings continued to grow, but prices started to decline.
# 3. Around 2015, following the announcement of regulations, uncertainty grew in the market. This led to a decrease in the number of AirBnBs and a rise in prices.
# 4. By 2019, once the regulations became the norm, the number of AirBnB listings increased again, resulting in prices decreasing due to higher supply.

# %% [markdown]
# <div style="background-color: #00A699; padding: 20px; border-radius: 10px; text-align: center;">
#   <h1 style="color: #000000; font-size: 32px; font-weight: bold;">
#     <strong> Recommendation for AirBnB </strong>
#   </h1>
# </div>

# %% [markdown]
# 1. Regulations on long-term rentals can negatively affect the business by causing both customer and host churn due to increased uncertainty.
# 2. Such regulations may lead to financial losses for AirBnB, which could be difficult to recover from in the future.
# 3. If customer experience is impacted, it may result in a negative brand perception.
# 4. It is advisable to monitor similar regulations in other regions and prepare accordingly.
# 5. AirBnB can anticipate and adapt to these regulations as they arise in different locations.
# 6. Implementing strict rules for onboarding and removing hosts can help maintain quality control.
# 7. Limiting the number of AirBnBs in a specific area could ensure enough rental options for the public and potentially prevent government intervention.
